# %%
# SPDX-FileCopyrightText: 2026 DLR e.V.
#
# SPDX-License-Identifier: MIT

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# for LaTeX support
# plt.rcParams.update({
#     "text.usetex": True,
#     "text.latex.preamble": "\\usepackage{amsmath}\\usepackage{amssymb}",
#     "savefig.bbox": "tight"
# })

# %%
df = pd.read_csv("correlation_results_aleatoric.csv")  # output of experiment_mse.bash
#df = pd.read_csv("correlation_results.csv")  # output of experiment_ood.bash
df.head()
# Out:
#   dataset uncertainty  seed  correlation        d2
# 0    wine         nac    42     0.045204  0.084065
# 1    wine         nac    43     0.214898  0.075662
# 2    wine         nac    44     0.161804  0.068765
# 3    wine    ensemble    42     0.160516  0.116341
# 4    wine    ensemble    43     0.599203  0.113288

# %%
sns.barplot(df, x="dataset", y="correlation", hue="uncertainty")
plt.xticks(rotation=90)
plt.savefig("regression_results.pgf")
plt.show()
